# %%
import sklearn
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install scikit-learn==1.3.0
# Out:
# Requirement already satisfied: scikit-learn==1.3.0 in c:\users\bhavi\anaconda\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\bhavi\anaconda\lib\site-packages (from scikit-learn==1.3.0) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\bhavi\anaconda\lib\site-packages (from scikit-learn==1.3.0) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\bhavi\anaconda\lib\site-packages (from scikit-learn==1.3.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bhavi\anaconda\lib\site-packages (from scikit-learn==1.3.0) (2.2.0)

# %%
#load the csv data
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#deleting id column
df=df.drop(columns = ['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#display basic stats of data
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#display no.of samples on each class
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#preprocessing dataset
#check null values
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Data analysis
df['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %%
#create list of colors and class labels
colors = ['blue','orange','red']
species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    #filter data on each class
    x = df[df['Species'] == species[i]]
    #plot the scatter plot
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'],c=colors[i],label=species[i])
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.legend()

# %%
for i in range(3):
    #filter data on each class
    x = df[df['Species'] == species[i]]
    #plot the scatter plot
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'],c=colors[i],label=species[i])
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()

# %%
for i in range(3):
    #filter data on each classs
    x=df[df['Species'] == species[i]]
    #plot the scatter plot
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'], c = colors[i],label=species[i])
plt.xlabel("SepalLengthCm")
plt.ylabel("PetalLengthCm")
plt.legend()

# %%
for i in range(3):
    #filter data on each class
    x = df[df['Species'] == species[i]]
    #plot the scatter plot
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'], c=colors[i], label=species[i])
plt.xlabel("SepalWidthCm")
plt.ylabel("PetalWidthCm")
plt.legend()

# %%
columns_for_correlation = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm','PetalWidthCm']  # Replace with your column names
correlation_matrix = df[columns_for_correlation].corr()
print(correlation_matrix)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
#correlation_matrix = df[columns_for_correlation].corr()
#plot the heat map
#fig, ax=plt.subplots(figsize(5, 4))
#sns.heatmap(correlation_matrix, annot=True, ax=ax, cmap='coolwarm')
fig, ax = plt.subplots(figsize=(5, 4))  # Corrected figsize syntax
sns.heatmap(correlation_matrix, annot=True, ax=ax, cmap='coolwarm')
plt.show()

# %%
#Model Training and Testing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import pickle

#input data
X = df.drop(columns=['Species'])
#output data
Y=df['Species']
#split the data for train and test
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.30)

# %%
#Logistic regression
model = LogisticRegression()
model.fit(x_train,y_train)
print("Logistic Regression Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Logistic Regression Accuracy:  97.77777777777777

# %%
#model training
model.fit(x_train.values,y_train.values)
# Out:
# LogisticRegression()

# %%
#print metric to get performance
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  97.77777777777777

# %%
#k-nearest neighbors
model = KNeighborsClassifier()
model.fit(x_train.values,y_train.values)
print("K-nearest neighbors Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# K-nearest neighbors Accuracy:  95.55555555555556

# %%
model.fit(x_train.values,y_train.values)
# Out:
# KNeighborsClassifier()

# %%
#print metric to get performance
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  95.55555555555556

# %%
#decisiom tree
model=DecisionTreeClassifier()
model.fit(x_train.values,y_train.values)
print("Decision Tree Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Decision Tree Accuracy:  93.33333333333333

# %%
model.fit(x_train.values,y_train.values)
# Out:
# DecisionTreeClassifier()

# %%
#print metric to get performance
print("Accuracy: ",model.score(x_test,y_test)*100)
# Out:
# Accuracy:  95.55555555555556
